# %%
import pandas as pd
import numpy as np

# %%
ejections = pd.read_csv('ejections.csv')

# %%
ejections['year'] = ejections['date'].str[-2:]

# %%
ejections.ye
# Out:
#           ab_id                                                des  event_num  \
# 0    2015003219  San Diego Padres center fielder Will Venable e...        732
# 1    2015003219  San Diego Padres Manager Bud Black ejected by ...        734
# 2    2015004134  Milwaukee Brewers second baseman Scooter Genne...        584
# 3    2015006692  Cincinnati Reds Manager Bryan Price ejected by...        557
# 4    2015008446  Pittsburgh Pirates Manager Clint Hurdle ejecte...        402
# 5    2015008724  New York Mets Manager Terry Collins ejected by...        319
# 6    2015010563  Tampa Bay Rays Manager Kevin Cash ejected by H...        519
# 7    2015010843  Baltimore Orioles pitcher Ubaldo Jimenez eject...        254
# 8    2015011598  Chicago Cubs Manager Joe Maddon ejected by HP ...        437
# 9    2015011738  Los Angeles Angels left fielder Collin Cowgill...        401
# 10   2015012524  Kansas City Royals pitcher Yordano Ventura eje...        211
# ...
